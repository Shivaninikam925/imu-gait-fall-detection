# %%
import arff
import pandas as pd

sample_file = r"C:\Users\Shivani\OneDrive\Documents\B.Tech\IMU-Gait-Fall-Detection\imu-gait-fall-detection\data\raw\WISDM_ar_v1.1\arff_files\phone\accel\data_1600_accel_phone.arff"

with open(sample_file, 'r') as f:
    data = arff.load(f)

df = pd.DataFrame(data['data'], columns=[attr[0] for attr in data['attributes']])
df.head()
# Out:
#   ACTIVITY     X0     X1     X2     X3     X4   X5   X6   X7   X8  ...  \
# 0        A  0.235  0.470  0.275  0.020  0.000  0.0  0.0  0.0  0.0  ...
# 1        A  0.275  0.440  0.270  0.015  0.000  0.0  0.0  0.0  0.0  ...
# 2        A  0.320  0.430  0.245  0.000  0.005  0.0  0.0  0.0  0.0  ...
# 3        A  0.315  0.495  0.185  0.005  0.000  0.0  0.0  0.0  0.0  ...
# 4        A  0.215  0.455  0.325  0.005  0.000  0.0  0.0  0.0  0.0  ...
#
#     ZMFCC11   ZMFCC12     XYCOS     XZCOS     YZCOS     XYCOR     XZCOR  \
# 0  0.486106  0.479859 -0.550668  0.049864  0.121354 -0.251024  0.164468
# 1  0.479571  0.473409 -0.633171  0.072129  0.161492 -0.386416  0.215680
# 2  0.483005  0.476798 -0.659493  0.087043  0.162157 -0.325151  0.272380
# 3  0.480711  0.474534 -0.712081  0.003810  0.210015 -0.364285  0.203131
# 4  0.468836  0.462811 -0.534933  0.047553  0.275833 -0.216423  0.238500
#
#       YZCOR  RESULTANT  class
# 0 -0.110722   10.05180   1600
# 1 -0.034375   10.11710   1600
# ...
